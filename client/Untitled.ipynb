# %%
import pandas as pd

# %%
import pickle
import urllib.request

class card:
     def __init__(self, name, cost, move_f, move_ch, move_tm, level, a_iv, d_iv, hp_iv, tm_flag, shiny, attack_stg, def_stg, health, energy, bonus_shield, status):
        self.name = name
        self.cost = cost
        self.move_f = move_f
        self.move_ch = move_ch
        self.move_tm = move_tm
        self.level = level
        self.a_iv = a_iv
        self.d_iv = d_iv
        self.hp_iv = hp_iv
        self.tm_flag = tm_flag
        self.attack_stg = attack_stg
        self.def_stg = def_stg
        self.shiny = shiny
        self.health = health
        self.energy = energy
        self.bonus_shield = bonus_shield
        self.status = status    
with open('pve_card_list.pkl', 'rb') as f:
    pve = pickle.load(f)
with open('card_list.pkl', 'rb') as f:
    pvp = pickle.load(f)

# %%
moves = pd.read_csv('moves/moves.csv')
types = pd.read_csv('moves/types.csv')
types = types[types.local_language_id == 9]

# %%
moves= moves.merge(types)

# %%
movelist = []
for key, value in pvp.items():
    movelist.append(value.move_f)
    movelist.append(value.move_ch)
    movelist.append(value.move_tm)
for key, value in pve.items():
    movelist.append(value.move_f)
    movelist.append(value.move_ch)
    movelist.append(value.move_tm)

# %%
mew_m_fast = ['SNARL', 'DRAGON_TAIL', 'VOLT_SWITCH', 'INFESTATION', 'SHADOW_CLAW', 'POUND', 'STEEL_WING', 'POISON_JAB', 'CHARGE_BEAM', 'FROST_BREATH', 'DRAGON_TAIL', 'ROCK_SMASH', 'WATERFALL']
mew_m_charged = ['ANCIENT_POWER','DRAGON_CLAW','ICE_BEAM','HYPER_BEAM','SOLAR_BEAM','THUNDER_BOLT','FLAME_CHARGE','LOW_SWEEP','ENERGY_BALL','STONE_EDGE','GYRO_BALL','DARK_PULSE','DAZZLING_GLEAM','SURF']
porygon_m_fast = [
    "HIDDEN_POWER_BUG",
    "HIDDEN_POWER_DARK",
    "HIDDEN_POWER_DRAGON",
    "HIDDEN_POWER_ELECTRIC",
    "HIDDEN_POWER_FIGHTING",
    "HIDDEN_POWER_FIRE",
    "HIDDEN_POWER_FLYING",
    "HIDDEN_POWER_GHOST",
    "HIDDEN_POWER_GRASS",
    "HIDDEN_POWER_GROUND",
    "HIDDEN_POWER_ICE",
    "HIDDEN_POWER_POISON",
    "HIDDEN_POWER_PSYCHIC",
    "HIDDEN_POWER_ROCK",
    "HIDDEN_POWER_STEEL",
    "HIDDEN_POWER_WATER",

    
]

movelist = movelist + mew_m_fast + mew_m_charged + porygon_m_fast

# %%
moveset = set(movelist)

# %%
moveset = pd.DataFrame(moveset)

# %%
moveset[0]= moveset[0].str.replace('_','-')

# %%
moveset['type'] = 'None'

# %%
df.iloc[0]
# Out:
# 'Water'

# %%
for i in range(moveset.shape[0]):
    df = moves[moves.identifier == moveset.loc[i,0].lower()].name
    if len(df) > 0:
        moveset.loc[ i, 'type'] = df.iloc[0]

# %%
moveset[moveset.type == 'None']
# Out:
#                          0  type
# 2     HIDDEN-POWER-PSYCHIC  None
# 4             THUNDERBOLT  None
# 6    HIDDEN-POWER-ELECTRIC  None
# 8      HIDDEN-POWER-GROUND  None
# 10      HIDDEN-POWER-GHOST  None
# 22       HIDDEN-POWER-FIRE  None
# 31   HIDDEN-POWER-FIGHTING  None
# 37      HIDDEN-POWER-STEEL  None
# 47      HIDDEN-POWER-WATER  None
# 53                    none  None
# 64     HIDDEN-POWER-POISON  None
# 71      HIDDEN-POWER-GRASS  None
# 99       HIDDEN-POWER-DARK  None
# 103       HIDDEN-POWER-BUG  None
# 104    HIDDEN-POWER-FLYING  None
# 109    HIDDEN-POWER-DRAGON  None
# 132      HIDDEN-POWER-ROCK  None
# 141       HIDDEN-POWER-ICE  None

# %%
moveset
# Out:
#                           0  type    HEX PSYSHOCK GRASS-KNOT     DIG  \
# 0                       HEX  None    NaN      NaN        NaN     NaN
# 1                  PSYSHOCK  None    NaN      NaN        NaN     NaN
# 2      HIDDEN-POWER-PSYCHIC  None    NaN      NaN        NaN     NaN
# 3                GRASS-KNOT  None    NaN      NaN        NaN     NaN
# 4              THUNDERBOLT  None    NaN      NaN        NaN     NaN
# 5                       DIG  None    NaN      NaN        NaN     NaN
# 6     HIDDEN-POWER-ELECTRIC  None    NaN      NaN        NaN     NaN
# 7               SHADOW-BALL  None    NaN      NaN        NaN     NaN
# 8       HIDDEN-POWER-GROUND  None    NaN      NaN        NaN     NaN
# 9                ROCK-SLIDE  None    NaN      NaN        NaN     NaN
# 10       HIDDEN-POWER-GHOST  None    NaN      NaN        NaN     NaN
# 11           POWER-UP-PUNCH  None    NaN      NaN        NaN     NaN
# 12                WATERFALL  None    NaN      NaN        NaN     NaN
# 13               AIR-CUTTER  None    NaN      NaN        NaN     NaN
# 14                 MUD-SLAP  None    NaN      NaN        NaN     NaN
# 15                  SCRATCH  None    NaN      NaN        NaN     NaN
# 16             FLAME-CHARGE  None    NaN      NaN        NaN     NaN
# 17                ICE-SHARD  None    NaN      NaN        NaN     NaN
# 18               SUPERPOWER  None    NaN      NaN        NaN     NaN
# 19                   CRUNCH  None    NaN      NaN        NaN     NaN
# 20                   TACKLE  None    NaN      NaN        NaN     NaN
# 21              KARATE-CHOP  None    NaN      NaN        NaN     NaN
# 22        HIDDEN-POWER-FIRE  None    NaN      NaN        NaN     NaN
# 23                     WRAP  None    NaN      NaN        NaN     NaN
# 24               POWER-WHIP  None    NaN      NaN        NaN     NaN
# 25               HYPER-FANG  None    NaN      NaN        NaN     NaN
# 26              WILD-CHARGE  None    NaN      NaN        NaN     NaN
# 27                POWER-GEM  None    NaN      NaN        NaN     NaN
# 28                     PECK  None    NaN      NaN        NaN     NaN
# 29                    SCALD  None    NaN      NaN        NaN     NaN
# ...                     ...   ...    ...      ...        ...     ...
# 133                    ACID  None    NaN      NaN        NaN     NaN
# 134              SKY-ATTACK  None    NaN      NaN        NaN     NaN
# 135             SILVER-WIND  None    NaN      NaN        NaN     NaN
# 136               IRON-TAIL  None    NaN      NaN        NaN     NaN
# 137             FLAME-BURST  None    NaN      NaN        NaN     NaN
# 138              SOLAR-BEAM  None    NaN      NaN        NaN     NaN
# 139                MUD-BOMB  None    NaN      NaN        NaN     NaN
# 140                STRUGGLE  None    NaN      NaN        NaN     NaN
# 141        HIDDEN-POWER-ICE  None    NaN      NaN        NaN     NaN
# 142           ANCIENT-POWER  None    NaN      NaN        NaN     NaN
# 143             ENERGY-BALL  None    NaN      NaN        NaN     NaN
# 144              ROCK-SMASH  None    NaN      NaN        NaN     NaN
# 145               BODY-SLAM  None    NaN      NaN        NaN     NaN
# 146                BUG-BITE  None    NaN      NaN        NaN     NaN
# 147                ICY-WIND  None    NaN      NaN        NaN     NaN
# 148               DISCHARGE  None    NaN      NaN        NaN     NaN
# 149            CLOSE-COMBAT  None    NaN      NaN        NaN     NaN
# 150            FLAMETHROWER  None    NaN      NaN        NaN     NaN
# 151             SHADOW-BONE  None    NaN      NaN        NaN     NaN
# 152                  SPLASH  None    NaN      NaN        NaN     NaN
# 153              DARK-PULSE  None    NaN      NaN        NaN     NaN
# 154          DAZZLING-GLEAM  None    NaN      NaN        NaN     NaN
# 155             NIGHT-SLASH  None    NaN      NaN        NaN     NaN
# 156               CONFUSION  None    NaN      NaN        NaN     NaN
# 157                MEGAHORN  None    NaN      NaN        NaN     NaN
# 158              METAL-CLAW  None    NaN      NaN        NaN     NaN
# 159             SLUDGE-BOMB  None    NaN      NaN        NaN     NaN
# 160               MOONBLAST  None    NaN      NaN        NaN     NaN
# 161                    SURF  None    NaN      NaN        NaN     NaN
# type                    NaN   NaN  Ghost  Psychic      Grass  Ground
#
#      SHADOW-BALL ROCK-SLIDE POWER-UP-PUNCH WATERFALL  ...  SPLASH DARK-PULSE  \
# 0            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 1            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 2            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 3            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 4            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 5            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 6            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 7            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 8            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 9            NaN        NaN            NaN       NaN  ...     NaN        NaN
# 10           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 11           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 12           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 13           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 14           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 15           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 16           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 17           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 18           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 19           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 20           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 21           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 22           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 23           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 24           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 25           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 26           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 27           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 28           NaN        NaN            NaN       NaN  ...     NaN        NaN
# 29           NaN        NaN            NaN       NaN  ...     NaN        NaN
# ...          ...        ...            ...       ...  ...     ...        ...
# 133          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 134          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 135          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 136          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 137          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 138          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 139          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 140          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 141          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 142          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 143          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 144          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 145          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 146          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 147          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 148          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 149          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 150          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 151          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 152          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 153          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 154          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 155          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 156          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 157          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 158          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 159          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 160          NaN        NaN            NaN       NaN  ...     NaN        NaN
# 161          NaN        NaN            NaN       NaN  ...     NaN        NaN
# type       Ghost       Rock       Fighting     Water  ...  Normal       Dark
#
#      DAZZLING-GLEAM NIGHT-SLASH CONFUSION MEGAHORN METAL-CLAW SLUDGE-BOMB  \
# 0               NaN         NaN       NaN      NaN        NaN         NaN
# 1               NaN         NaN       NaN      NaN        NaN         NaN
# 2               NaN         NaN       NaN      NaN        NaN         NaN
# 3               NaN         NaN       NaN      NaN        NaN         NaN
# 4               NaN         NaN       NaN      NaN        NaN         NaN
# 5               NaN         NaN       NaN      NaN        NaN         NaN
# 6               NaN         NaN       NaN      NaN        NaN         NaN
# 7               NaN         NaN       NaN      NaN        NaN         NaN
# 8               NaN         NaN       NaN      NaN        NaN         NaN
# 9               NaN         NaN       NaN      NaN        NaN         NaN
# 10              NaN         NaN       NaN      NaN        NaN         NaN
# 11              NaN         NaN       NaN      NaN        NaN         NaN
# 12              NaN         NaN       NaN      NaN        NaN         NaN
# 13              NaN         NaN       NaN      NaN        NaN         NaN
# 14              NaN         NaN       NaN      NaN        NaN         NaN
# 15              NaN         NaN       NaN      NaN        NaN         NaN
# 16              NaN         NaN       NaN      NaN        NaN         NaN
# 17              NaN         NaN       NaN      NaN        NaN         NaN
# 18              NaN         NaN       NaN      NaN        NaN         NaN
# 19              NaN         NaN       NaN      NaN        NaN         NaN
# 20              NaN         NaN       NaN      NaN        NaN         NaN
# 21              NaN         NaN       NaN      NaN        NaN         NaN
# 22              NaN         NaN       NaN      NaN        NaN         NaN
# 23              NaN         NaN       NaN      NaN        NaN         NaN
# 24              NaN         NaN       NaN      NaN        NaN         NaN
# 25              NaN         NaN       NaN      NaN        NaN         NaN
# 26              NaN         NaN       NaN      NaN        NaN         NaN
# 27              NaN         NaN       NaN      NaN        NaN         NaN
# 28              NaN         NaN       NaN      NaN        NaN         NaN
# 29              NaN         NaN       NaN      NaN        NaN         NaN
# ...             ...         ...       ...      ...        ...         ...
# 133             NaN         NaN       NaN      NaN        NaN         NaN
# 134             NaN         NaN       NaN      NaN        NaN         NaN
# 135             NaN         NaN       NaN      NaN        NaN         NaN
# 136             NaN         NaN       NaN      NaN        NaN         NaN
# 137             NaN         NaN       NaN      NaN        NaN         NaN
# 138             NaN         NaN       NaN      NaN        NaN         NaN
# 139             NaN         NaN       NaN      NaN        NaN         NaN
# 140             NaN         NaN       NaN      NaN        NaN         NaN
# 141             NaN         NaN       NaN      NaN        NaN         NaN
# 142             NaN         NaN       NaN      NaN        NaN         NaN
# 143             NaN         NaN       NaN      NaN        NaN         NaN
# 144             NaN         NaN       NaN      NaN        NaN         NaN
# 145             NaN         NaN       NaN      NaN        NaN         NaN
# 146             NaN         NaN       NaN      NaN        NaN         NaN
# 147             NaN         NaN       NaN      NaN        NaN         NaN
# 148             NaN         NaN       NaN      NaN        NaN         NaN
# 149             NaN         NaN       NaN      NaN        NaN         NaN
# 150             NaN         NaN       NaN      NaN        NaN         NaN
# 151             NaN         NaN       NaN      NaN        NaN         NaN
# 152             NaN         NaN       NaN      NaN        NaN         NaN
# 153             NaN         NaN       NaN      NaN        NaN         NaN
# 154             NaN         NaN       NaN      NaN        NaN         NaN
# 155             NaN         NaN       NaN      NaN        NaN         NaN
# 156             NaN         NaN       NaN      NaN        NaN         NaN
# 157             NaN         NaN       NaN      NaN        NaN         NaN
# 158             NaN         NaN       NaN      NaN        NaN         NaN
# 159             NaN         NaN       NaN      NaN        NaN         NaN
# 160             NaN         NaN       NaN      NaN        NaN         NaN
# 161             NaN         NaN       NaN      NaN        NaN         NaN
# type          Fairy        Dark   Psychic      Bug      Steel      Poison
#
#      MOONBLAST   SURF
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# 5          NaN    NaN
# 6          NaN    NaN
# 7          NaN    NaN
# 8          NaN    NaN
# 9          NaN    NaN
# 10         NaN    NaN
# 11         NaN    NaN
# 12         NaN    NaN
# 13         NaN    NaN
# 14         NaN    NaN
# 15         NaN    NaN
# 16         NaN    NaN
# 17         NaN    NaN
# 18         NaN    NaN
# 19         NaN    NaN
# 20         NaN    NaN
# 21         NaN    NaN
# 22         NaN    NaN
# 23         NaN    NaN
# 24         NaN    NaN
# 25         NaN    NaN
# 26         NaN    NaN
# 27         NaN    NaN
# 28         NaN    NaN
# 29         NaN    NaN
# ...        ...    ...
# 133        NaN    NaN
# 134        NaN    NaN
# 135        NaN    NaN
# 136        NaN    NaN
# 137        NaN    NaN
# 138        NaN    NaN
# 139        NaN    NaN
# 140        NaN    NaN
# 141        NaN    NaN
# 142        NaN    NaN
# 143        NaN    NaN
# 144        NaN    NaN
# 145        NaN    NaN
# 146        NaN    NaN
# 147        NaN    NaN
# 148        NaN    NaN
# 149        NaN    NaN
# 150        NaN    NaN
# 151        NaN    NaN
# 152        NaN    NaN
# 153        NaN    NaN
# 154        NaN    NaN
# 155        NaN    NaN
# 156        NaN    NaN
# 157        NaN    NaN
# 158        NaN    NaN
# 159        NaN    NaN
# 160        NaN    NaN
# 161        NaN    NaN
# type     Fairy  Water
#
# [163 rows x 146 columns]
